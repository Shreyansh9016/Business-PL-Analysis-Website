# %%
import pandas as pd

# %%
df = pd.read_csv('Prod_Env_Inventory_Dataset.csv')
df.to_json('inventory.json', orient='records')

# %%
df = pd.read_csv('Products_PROD.csv')
df.to_json('products.json', orient='records')
